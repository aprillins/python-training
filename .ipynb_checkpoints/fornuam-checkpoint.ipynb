# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.dates as dates
from matplotlib.dates import (YEARLY, DateFormatter, WeekdayLocator,
                              rrulewrapper, RRuleLocator, drange, MonthLocator)

csvfile = pd.read_csv('nuama.csv', header=1)
csvfile = csvfile[2:]
csvfile.columns = ['period', 'date', 'metric', 'new_user', 'user_loss', 'notes']
index = ['date', 'new_user', 'user_loss']
csvfile = csvfile[index]
csvfile = csvfile.drop_duplicates(subset='date', keep='last')
cdt, cnu, cul = csvfile['date'], csvfile['new_user'], csvfile['user_loss']
cdt = cdt.astype('O')
cnu = cnu.str.replace(',', '', regex=False)
cnu = cnu.astype(int)
cul = cul.str.replace(',', '', regex=False)
cul = cul.astype(int)
csvfile['date'], csvfile['new_user'], csvfile['user_loss'] = cdt, cnu, cul
csvfile = csvfile.sort_values(by='date', ascending=True)
csvfile.reset_index(drop=True, inplace=True)
csvfile['date'] = pd.to_datetime(csvfile['date'])
csvfile['date'] = csvfile['date'].dt.date
csvfile.set_index('date', inplace=True)
csvfile['delta'] = csvfile['new_user'] - csvfile['user_loss']
# csvfile.plot(x='date', figsize=(20,10), rot=45).grid(color='r', axis='x', linestyle='--')


z, ax = plt.subplots(figsize=(20,10))
csvfile.plot(ax=ax, rot=90).grid(axis='x')
ax.xaxis.set_major_locator(dates.WeekdayLocator())
ax.xaxis.set_major_formatter(dates.DateFormatter('%A, %d-%m-%Y'))
# dir(ax)
# help(csvfile.plot)

# %%
import pandas as pd
import matplotlib.pyplot as plt

date_time = ["2011-09-01", "2011-08-01", "2011-07-01", "2011-06-01", "2011-05-01"]
date_time = pd.to_datetime(date_time)
temp = [2, 4, 6, 4, 6]

DF = pd.DataFrame()
DF['temp'] = temp
DF = DF.set_index(date_time)

fig, ax = plt.subplots()
fig.subplots_adjust(bottom=0.3)
plt.xticks(rotation=90)
plt.plot(DF)
